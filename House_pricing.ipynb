# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import data
df = pd.read_csv('drive/MyDrive/ML Reloaded/Data/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Note
# For continuous columns (Age, price) use distplot, for categorical use countplot

# %%
sns.countplot(df['bedrooms'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.scatterplot(x= 'price', y = 'long', data = df)

# %%
plt.figure(figsize= (10,8))
sns.scatterplot(x= 'price', y = 'lat', data = df)

# %%
plt.figure(figsize= (10,8))
sns.scatterplot(x= 'long', y = 'lat', data = df, hue = 'price')

# %%
df.sort_values('price', ascending=False)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
### There are some houses with outlying prices so we drop the top 1% houses 
non_top_1_perc = df.sort_values('price', ascending=False).iloc[216:]

# %%
sns.distplot(non_top_1_perc['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize= (10,8))
sns.scatterplot(x= 'long', y = 'lat', data = non_top_1_perc, edgecolor = None, alpha= 0.2, palette= 'RdYlGn', hue = 'price')

# %% [markdown]
# It is evident the houses closer to the water/sea are more expensive, which is only normal

# %%
# The id column doesn't seem to have any use or trend so we can drop it
df = df.drop('id', axis= 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21597 non-null  object
#  1   price          21597 non-null  float64
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  int64
#  8   view           21597 non-null  int64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  int64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
# ...

# %%
# The date column is a string, so we change it to datetime format
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21597 non-null  datetime64[ns]
#  1   price          21597 non-null  float64
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  int64
#  8   view           21597 non-null  int64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  int64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
# ...

# %%
# Now let's sort according to date
df.sort_values('date', ascending = False)
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 16580 2015-05-27  1310000.0         4       2.25         3750      5000
# 13040 2015-05-24   445500.0         2       1.75         1390      6670
# 5632  2015-05-15   450000.0         5       2.00         1870      7344
# 15797 2015-05-14   440000.0         5       2.00         1430      5600
# 927   2015-05-14   359000.0         2       2.75         1370      1140
# ...          ...        ...       ...        ...          ...       ...
# 7316  2014-05-02   435000.0         4       1.00         1450      8800
# 19661 2014-05-02   785000.0         5       3.25         3660     11995
# 6418  2014-05-02   257950.0         3       1.75         1370      5858
# 10689 2014-05-02   499950.0         4       2.50         2860      3345
# 4959  2014-05-02   588500.0         3       1.75         2330     14892
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
sns.distplot(df['yr_renovated'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['year'] = df['date'].dt.year

# %%
df['month'] = df['date'].dt.month

# %%
df['day_of_the_month'] = df['date'].dt.day

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  yr_built  yr_renovated  \
# ...

# %%
df.groupby('month').mean()['price'].sort_values()
# Out:
# month
# 2     508520.051323
# 11    522359.903478
# 12    524799.902041
# 1     525963.251534
# 9     529723.517787
# 8     536655.212481
# 10    539439.447228
# 3     544057.683200
# 7     544892.161013
# 5     550849.746893
# 6     557534.318182
# 4     562215.615074
# Name: price, dtype: float64

# %% [markdown]
# Sale price is lowest in winter months and highest in spring months

# %%
#we can drop zip code because we cant turn it into a category, there are 70 categories (Too many). We can also drop date column
df.drop(['date', 'zipcode'], axis= 1, inplace= True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month  day_of_the_month
# ...

# %%
def renovation():
  '''
  This is a function to make the yr renovated column a categorical column
  '''
  x = df['yr_renovated']
  y = []
  for i in x:
    if x[i] == 0:
      y.append(0)
    else:
      y.append(1)
  return y

# %%
x = df['yr_renovated']
y = []
for i in x:
  if x[i] == 0:
    y.append(0)
  else:
    y.append(1)

# %%
renovated = y

# %%
df['renovated'] = pd.DataFrame(renovated)

# %%
df['renovated'].value_counts()
# Out:
# 0    21571
# 1       26
# Name: renovated, dtype: int64

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  yr_built  yr_renovated  \
# 0               0     0          3      7  ...      1955             0
# ...

# %%
y.count(0)
# Out:
# 21571

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  yr_built  yr_renovated  \
# 0               0     0          3      7  ...      1955             0
# ...

# %%
# Now let's split
X = df.drop('price', axis = 1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state= 101)

# %%
#Scaling
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Note
# we only transform test set, we dont fit

# %%
# Now the model
#!pip install tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape, X_test.shape, y_test.shape
# Out:
# ((15117, 21), (6480, 21), (6480,))

# %%
model = Sequential()

# Input
model.add(Dense(21, activation= 'relu'))
model.add(Dense(21, activation= 'relu'))
model.add(Dense(21, activation= 'relu'))
model.add(Dense(21, activation= 'relu'))

# output
model.add(Dense(1))

model.compile(optimizer= 'adam', loss = 'mse')

# %%
model.fit(x= X_train, y= y_train, validation_data=(X_test,y_test), batch_size=128, epochs = 400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 8ms/step - loss: 430226374656.0000 - val_loss: 418841165824.0000
# Epoch 2/400
# 119/119 [==============================] - 1s 6ms/step - loss: 428429377536.0000 - val_loss: 412826501120.0000
# Epoch 3/400
# 119/119 [==============================] - 1s 8ms/step - loss: 406127476736.0000 - val_loss: 363249729536.0000
# Epoch 4/400
# 119/119 [==============================] - 1s 6ms/step - loss: 306693439488.0000 - val_loss: 213404614656.0000
# Epoch 5/400
# 119/119 [==============================] - 1s 9ms/step - loss: 151847436288.0000 - val_loss: 104052228096.0000
# Epoch 6/400
# 119/119 [==============================] - 1s 8ms/step - loss: 103237017600.0000 - val_loss: 98057158656.0000
# Epoch 7/400
# 119/119 [==============================] - 1s 8ms/step - loss: 100545273856.0000 - val_loss: 96393232384.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses
# Out:
#              loss      val_loss
# 0    4.302264e+11  4.188412e+11
# 1    4.284294e+11  4.128265e+11
# 2    4.061275e+11  3.632497e+11
# 3    3.066934e+11  2.134046e+11
# 4    1.518474e+11  1.040522e+11
# ..            ...           ...
# 395  2.961688e+10  2.757975e+10
# 396  2.958406e+10  2.755003e+10
# 397  2.958052e+10  2.765003e+10
# 398  2.955665e+10  2.758513e+10
# 399  2.954522e+10  2.753007e+10
#
# [400 rows x 2 columns]

# %%
losses.plot()
plt.figure(figsize= (10,10))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([[399772.16],
#        [586947.25],
#        [570116.2 ],
#        ...,
#        [372570.16],
#        [557829.2 ],
#        [680292.94]], dtype=float32)

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 165921.88006859715

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 102633.72283468365

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.7924085796668077

# %%
plt.figure(figsize= (10,8))
plt.scatter(y_test, predictions)

# %%
# To predict for a new house
single_house = df.drop('price', axis= 1).iloc[0]

# %%
# Now we need to scale and transform(not fit cos its not training), but we make it a numpy array first, collect values and reshape it to (-1,21)
single_house = scaler.transform(single_house.values.reshape(-1,21))

# %%
single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182, 0.4       ,
#         0.        ]])

# %%
model.predict(single_house)
# Out:
# array([[284047.4]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price               221900.0000
# bedrooms                 3.0000
# bathrooms                1.0000
# sqft_living           1180.0000
# sqft_lot              5650.0000
# floors                   1.0000
# waterfront               0.0000
# view                     0.0000
# condition                3.0000
# grade                    7.0000
# sqft_above            1180.0000
# sqft_basement            0.0000
# yr_built              1955.0000
# yr_renovated             0.0000
# lat                     47.5112
# long                  -122.2570
# sqft_living15         1340.0000
# sqft_lot15            5650.0000
# year                  2014.0000
# month                   10.0000
# day_of_the_month        13.0000
# renovated                0.0000
# Name: 0, dtype: float64

# %% [markdown]
# The difference is not so bad, but it can be better if the model is trained without the presence of the extreme values

# %%
# Let's look at the top 1 percent again
df.sort_values(by = 'price', ascending = False)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7245   7700000.0         6       8.00        12050     27600     2.5
# 3910   7060000.0         5       4.50        10040     37325     2.0
# 9245   6890000.0         6       7.75         9890     31374     2.0
# 4407   5570000.0         5       5.75         9200     35069     2.0
# 1446   5350000.0         5       5.00         8000     23985     2.0
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  ...  yr_built  yr_renovated  \
# ...

# %%
#Taking the bottom 98% of our data
bottom_98_percent = df.sort_values('price', ascending= False).iloc[432:]

# %%
bottom_98_percent.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20436  1600000.0         4       5.50         6530    871200     2.0
# 12088  1600000.0         5       3.00         3640      8239     2.0
# 19912  1600000.0         4       4.25         4645      7757     2.0
# 2618   1600000.0         5       4.50         5130     43123     2.0
# 16287  1600000.0         3       2.25         3170      5000     2.0
#
#        waterfront  view  condition  grade  ...  yr_built  yr_renovated  \
# 20436           0     2          3     11  ...      2008             0
# 12088           0     3          3     10  ...      1982             0
# 19912           0     0          3     10  ...      2006             0
# 2618            0     0          3     11  ...      1996             0
# 16287           0     0          5     10  ...      1975             0
#
#            lat     long  sqft_living15  sqft_lot15  year  month  \
# ...

# %%
# Converting the renovated year column to categorical
x = bottom_98_percent['yr_renovated'].tolist()
y = []
for i in x:
  if i == 0:
    y.append(0)
  else:
    y.append(1)

# %%
bottom_98_percent['yr_renovated'].tolist().count(0), y.count(0), y.count(1)
# Out:
# (20318, 20318, 847)

# %%
bottom_98_percent['renovated'] = y

# %%
bottom_98_percent['renovated'].isna().sum()
# Out:
# 0

# %%
bottom_98_percent['yr_renovated'].isna().sum()
# Out:
# 0

# %%
bottom_98_percent['yr_renovated'].value_counts()
# Out:
# 0       20318
# 2014       89
# 2013       36
# 2005       33
# 2007       32
#         ...
# 1954        1
# 1934        1
# 1948        1
# 1959        1
# 1951        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
bottom_98_percent.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20436  1600000.0         4       5.50         6530    871200     2.0
# 12088  1600000.0         5       3.00         3640      8239     2.0
# 19912  1600000.0         4       4.25         4645      7757     2.0
# 2618   1600000.0         5       4.50         5130     43123     2.0
# 16287  1600000.0         3       2.25         3170      5000     2.0
#
#        waterfront  view  condition  grade  ...  yr_built  yr_renovated  \
# 20436           0     2          3     11  ...      2008             0
# 12088           0     3          3     10  ...      1982             0
# 19912           0     0          3     10  ...      2006             0
# 2618            0     0          3     11  ...      1996             0
# 16287           0     0          5     10  ...      1975             0
#
#            lat     long  sqft_living15  sqft_lot15  year  month  \
# ...

# %%
# Seperating into train and test set
X = bottom_98_percent.drop('price', axis = 1).values
y = bottom_98_percent['price'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state= 101)

# %%
#scaling
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Training the model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# Input
model.add(Dense(20, activation = 'relu'))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(20, activation = 'relu'))

# Output
model.add(Dense(1))

model.compile(optimizer= 'adam', loss= 'mse')

# %%
# Fit the model
model.fit(x= X_train, y= y_train, validation_data=(X_test,y_test), batch_size=128, epochs = 400)
# Out:
# Epoch 1/400
# 116/116 [==============================] - 1s 5ms/step - loss: 318704025600.0000 - val_loss: 328115322880.0000
# Epoch 2/400
# 116/116 [==============================] - 0s 3ms/step - loss: 317737992192.0000 - val_loss: 324770267136.0000
# Epoch 3/400
# 116/116 [==============================] - 0s 4ms/step - loss: 304998711296.0000 - val_loss: 295131414528.0000
# Epoch 4/400
# 116/116 [==============================] - 0s 3ms/step - loss: 242726928384.0000 - val_loss: 191125307392.0000
# Epoch 5/400
# 116/116 [==============================] - 0s 4ms/step - loss: 117628182528.0000 - val_loss: 67251040256.0000
# Epoch 6/400
# 116/116 [==============================] - 0s 3ms/step - loss: 49099427840.0000 - val_loss: 46543982592.0000
# Epoch 7/400
# 116/116 [==============================] - 0s 4ms/step - loss: 44064993280.0000 - val_loss: 45721452544.0000
# Epoch 8/400
# ...

# %%
loss = pd.DataFrame(model.history.history)

# %%
loss.plot()

# %%
# predictions
predictions = model.predict(X_test)

# %%
plt.scatter(y_test, predictions)

# %%
# Showing prediction on a random data set
data_1 = bottom_98_percent.drop('price', axis= 1).iloc[0]

# %%
bottom_98_percent.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20436  1600000.0         4       5.50         6530    871200     2.0
# 12088  1600000.0         5       3.00         3640      8239     2.0
# 19912  1600000.0         4       4.25         4645      7757     2.0
# 2618   1600000.0         5       4.50         5130     43123     2.0
# 16287  1600000.0         3       2.25         3170      5000     2.0
#
#        waterfront  view  condition  grade  ...  yr_built  yr_renovated  \
# 20436           0     2          3     11  ...      2008             0
# 12088           0     3          3     10  ...      1982             0
# 19912           0     0          3     10  ...      2006             0
# 2618            0     0          3     11  ...      1996             0
# 16287           0     0          5     10  ...      1975             0
#
#            lat     long  sqft_living15  sqft_lot15  year  month  \
# ...

# %%
data_1 = data_1.values.reshape(-1,21)
data_1 = scaler.transform(data_1)

# %%
data_1
# Out:
# array([[0.33333333, 0.8       , 0.86638537, 0.74781351, 0.4       ,
#         0.        , 0.5       , 0.5       , 0.875     , 0.88633094,
#         0.        , 0.93913043, 0.        , 0.81627042, 0.53239203,
#         0.15384615, 0.98498878, 1.        , 0.27272727, 0.46666667,
#         0.        ]])

# %%
bottom_98_percent.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.116500e+04  21165.000000  21165.000000  21165.000000  2.116500e+04
# mean   5.056454e+05      3.355256      2.085967   2030.185589  1.481862e+04
# std    2.566801e+05      0.917444      0.734856    834.203923  4.040925e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.200000e+05      3.000000      1.500000   1410.000000  5.004000e+03
# 50%    4.460000e+05      3.000000      2.250000   1890.000000  7.560000e+03
# 75%    6.260000e+05      4.000000      2.500000   2500.000000  1.048800e+04
# max    1.600000e+06     33.000000      7.500000   7480.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21165.000000  21165.000000  21165.000000  21165.000000  21165.000000
# mean       1.486322      0.004252      0.203922      3.408079      7.602126
# ...

# %%
model.predict(data_1), # This is the prediction without making renovated categorical array([[1305526.9]], dtype=float32)
# Out:
# (array([[1270698.]], dtype=float32),)

# %%
bottom_98_percent['price'].iloc[0]
# Out:
# 1600000.0

# %%
# This is now closer but can still be better. lets gooooo
# Converting the renovated year column to categorical definitely makes it worse, so its not recommended
